# %%
# YOLO-Powered Hand Proximity Warning System with Virtual Object Zone

# %%
# !pip install ultralytics opencv-python

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import time

# -------------------------------
# 1. Initialize Webcam & ROI
# -------------------------------
cap = cv2.VideoCapture(0)
ret, frame = cap.read()
if not ret:
    print("Cannot open camera")
    exit()

# Let user select virtual object ROI
roi = cv2.selectROI("Select Virtual Object", frame, showCrosshair=True, fromCenter=False)
cv2.destroyWindow("Select Virtual Object")
x, y, w, h = roi
vx1, vy1, vx2, vy2 = x, y, x + w, y + h
obj_center = (x + w // 2, y + h // 2)

# -------------------------------
# 2. Load YOLO 3-class hand model
# -------------------------------
model = YOLO('https://huggingface.co/EtanHey/hand-detection-3class/resolve/main/model.pt')

# -------------------------------
# 3. Main Loop
# -------------------------------
while True:
    start_time = time.time()
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, device='cpu', imgsz=640)

    hand_center = None

    for r in results:
        if r.boxes is not None:
            for box in r.boxes:
                class_id = int(box.cls[0])
                conf = float(box.conf[0])
                if class_id == 1:  # hand only
                    x1, y1, x2, y2 = map(int, box.xyxy[0])
                    cx = (x1 + x2) // 2
                    cy = (y1 + y2) // 2
                    hand_center = (cx, cy)

                    # Draw bounding box and label
                    classes = ['arm', 'hand', 'not_hand']
                    label = f"{classes[class_id]} {conf:.0%}"
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 255), 2)
                    cv2.putText(frame, label, (x1, y1-10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,255), 2)

    # -------------------------------
    # Distance-based state
    # -------------------------------
    state = "SAFE"
    color = (0, 255, 0)
    if hand_center is not None:
        dist = int(np.linalg.norm(np.array(hand_center) - np.array(obj_center)))
        if dist > 120:
            state = "SAFE"
            color = (0, 255, 0)
        elif dist <= 120 and dist > 60:
            state = "WARNING"
            color = (0, 255, 255)
        else:
            state = "DANGER"
            color = (0, 0, 255)
        cv2.putText(frame, f"Distance: {dist}px", (20, 40),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # Draw virtual object
    cv2.rectangle(frame, (vx1, vy1), (vx2, vy2), color, 3)
    cv2.circle(frame, obj_center, 6, color, -1)

    # Display state
    cv2.putText(frame, state, (20, 80),
                cv2.FONT_HERSHEY_SIMPLEX, 1.2, color, 3)
    if state == "DANGER":
        cv2.putText(frame, "DANGER DANGER", (80, 130),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.4, (0, 0, 255), 4)

    # Display FPS
    fps = 1 / (time.time() - start_time)
    cv2.putText(frame, f"FPS: {fps:.1f}", (20, 160),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)

    cv2.imshow("Hand Detection + Virtual Object", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Found https://huggingface.co/EtanHey/hand-detection-3class/resolve/main/model.pt locally at weights/model.pt
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.02, 56.7ms
# Speed: 24.8ms preprocess, 56.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 38.5ms
# Speed: 12.6ms preprocess, 38.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.02, 37.0ms
# Speed: 11.3ms preprocess, 37.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.02, 33.6ms
# Speed: 10.2ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.02, 34.4ms
# Speed: 11.5ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.02, 31.1ms
# Speed: 10.0ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.02, 36.3ms
# Speed: 10.7ms preprocess, 36.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.02, 38.7ms
# Speed: 14.5ms preprocess, 38.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 39.4ms
# Speed: 11.3ms preprocess, 39.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.03, arm 0.01, 39.4ms
# Speed: 12.0ms preprocess, 39.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.02, 33.7ms
# Speed: 10.3ms preprocess, 33.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.9ms
# Speed: 10.8ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 30.7ms
# Speed: 10.8ms preprocess, 30.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.5ms
# Speed: 10.1ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.03, arm 0.01, 34.8ms
# Speed: 10.4ms preprocess, 34.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.03, arm 0.01, 31.9ms
# Speed: 10.3ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 30.4ms
# Speed: 10.7ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 30.5ms
# Speed: 10.5ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 32.0ms
# Speed: 10.6ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 29.0ms
# Speed: 10.4ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.03, arm 0.01, 108.4ms
# Speed: 16.1ms preprocess, 108.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 121.1ms
# Speed: 15.2ms preprocess, 121.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.01, 101.8ms
# Speed: 16.3ms preprocess, 101.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 140.4ms
# Speed: 25.0ms preprocess, 140.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 48.0ms
# Speed: 12.9ms preprocess, 48.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.03, arm 0.01, 37.3ms
# Speed: 10.8ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 35.9ms
# Speed: 11.4ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.02, arm 0.01, 39.2ms
# Speed: 10.3ms preprocess, 39.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 35.3ms
# Speed: 10.4ms preprocess, 35.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 42.6ms
# Speed: 10.7ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 37.1ms
# Speed: 10.5ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 33.3ms
# Speed: 9.7ms preprocess, 33.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 35.7ms
# Speed: 9.2ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 30.6ms
# Speed: 10.3ms preprocess, 30.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.0ms
# Speed: 10.3ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 34.0ms
# Speed: 10.5ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.03, arm 0.01, 41.2ms
# Speed: 11.9ms preprocess, 41.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 33.8ms
# Speed: 10.9ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.3ms
# Speed: 10.2ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 33.4ms
# Speed: 10.2ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.2ms
# Speed: 9.8ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 38.9ms
# Speed: 10.7ms preprocess, 38.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 34.2ms
# Speed: 11.1ms preprocess, 34.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.03, arm 0.01, 33.1ms
# Speed: 10.2ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 48.7ms
# Speed: 13.0ms preprocess, 48.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 46.3ms
# Speed: 11.4ms preprocess, 46.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 41.4ms
# Speed: 12.5ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.98, hand 0.02, arm 0.00, 39.6ms
# Speed: 9.8ms preprocess, 39.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.03, arm 0.01, 40.5ms
# Speed: 10.5ms preprocess, 40.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 33.0ms
# Speed: 10.2ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 32.9ms
# Speed: 10.1ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.6ms
# Speed: 11.2ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 35.0ms
# Speed: 10.1ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 36.2ms
# Speed: 10.5ms preprocess, 36.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 38.3ms
# Speed: 10.5ms preprocess, 38.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 36.6ms
# Speed: 10.5ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.1ms
# Speed: 10.1ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 30.2ms
# Speed: 9.7ms preprocess, 30.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.4ms
# Speed: 10.5ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 33.2ms
# Speed: 10.0ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.9ms
# Speed: 10.1ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.01, 32.6ms
# Speed: 10.1ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.7ms
# Speed: 9.9ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.8ms
# Speed: 10.2ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 31.9ms
# Speed: 10.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.03, arm 0.01, 31.6ms
# Speed: 10.7ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 33.3ms
# Speed: 10.1ms preprocess, 33.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.3ms
# Speed: 9.9ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 33.0ms
# Speed: 10.1ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 38.7ms
# Speed: 10.4ms preprocess, 38.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 35.4ms
# Speed: 11.8ms preprocess, 35.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 36.1ms
# Speed: 9.4ms preprocess, 36.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 37.1ms
# Speed: 10.4ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.93, hand 0.05, arm 0.01, 35.5ms
# Speed: 10.0ms preprocess, 35.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 31.6ms
# Speed: 12.7ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.01, 37.2ms
# Speed: 10.3ms preprocess, 37.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 32.0ms
# Speed: 10.2ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 33.5ms
# Speed: 10.1ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.6ms
# Speed: 9.8ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.1ms
# Speed: 12.1ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 31.3ms
# Speed: 9.7ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.93, hand 0.06, arm 0.01, 33.2ms
# Speed: 10.3ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.93, hand 0.06, arm 0.01, 34.1ms
# Speed: 10.5ms preprocess, 34.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 33.7ms
# Speed: 10.2ms preprocess, 33.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 37.9ms
# Speed: 10.9ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 33.6ms
# Speed: 10.6ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.93, hand 0.06, arm 0.01, 35.3ms
# Speed: 10.3ms preprocess, 35.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 32.5ms
# Speed: 10.3ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.01, 31.3ms
# Speed: 10.7ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.01, 32.6ms
# Speed: 10.6ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 39.3ms
# Speed: 10.8ms preprocess, 39.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 34.4ms
# Speed: 11.2ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.6ms
# Speed: 10.5ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.1ms
# Speed: 9.8ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.7ms
# Speed: 10.2ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 32.6ms
# Speed: 10.1ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.1ms
# Speed: 10.3ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.6ms
# Speed: 10.1ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 36.6ms
# Speed: 10.1ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 45.7ms
# Speed: 11.9ms preprocess, 45.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 40.2ms
# Speed: 11.7ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 35.6ms
# Speed: 9.5ms preprocess, 35.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 38.0ms
# Speed: 10.7ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 49.2ms
# Speed: 11.6ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 36.3ms
# Speed: 10.6ms preprocess, 36.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 32.9ms
# Speed: 10.6ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.92, hand 0.06, arm 0.02, 32.6ms
# Speed: 10.4ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.0ms
# Speed: 10.4ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.7ms
# Speed: 10.4ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 33.0ms
# Speed: 10.3ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 31.2ms
# Speed: 10.1ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 35.2ms
# Speed: 10.2ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 32.8ms
# Speed: 10.3ms preprocess, 32.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.3ms
# Speed: 10.2ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.03, arm 0.01, 30.8ms
# Speed: 10.1ms preprocess, 30.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 32.7ms
# Speed: 10.5ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.3ms
# Speed: 10.5ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 32.9ms
# Speed: 10.6ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 31.8ms
# Speed: 9.9ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.05, arm 0.01, 33.5ms
# Speed: 10.6ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 30.7ms
# Speed: 10.3ms preprocess, 30.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 32.8ms
# Speed: 10.3ms preprocess, 32.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.4ms
# Speed: 10.6ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.5ms
# Speed: 10.1ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 30.9ms
# Speed: 10.2ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 32.7ms
# Speed: 10.2ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 38.1ms
# Speed: 10.6ms preprocess, 38.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 39.2ms
# Speed: 10.4ms preprocess, 39.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 37.8ms
# Speed: 10.3ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 45.8ms
# Speed: 10.7ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 33.4ms
# Speed: 10.7ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 31.6ms
# Speed: 10.2ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 32.0ms
# Speed: 10.4ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 32.0ms
# Speed: 10.7ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 31.2ms
# Speed: 10.6ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 36.7ms
# Speed: 10.2ms preprocess, 36.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 42.0ms
# Speed: 13.2ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 40.6ms
# Speed: 12.0ms preprocess, 40.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 37.0ms
# Speed: 11.6ms preprocess, 37.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.05, arm 0.01, 36.9ms
# Speed: 11.6ms preprocess, 36.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 32.2ms
# Speed: 10.3ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.1ms
# Speed: 10.4ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.7ms
# Speed: 10.8ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.03, arm 0.01, 30.6ms
# Speed: 10.5ms preprocess, 30.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.00, 32.0ms
# Speed: 11.3ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.0ms
# Speed: 10.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.03, arm 0.01, 37.7ms
# Speed: 10.6ms preprocess, 37.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 40.5ms
# Speed: 10.4ms preprocess, 40.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 33.9ms
# Speed: 12.1ms preprocess, 33.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 31.6ms
# Speed: 10.2ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 31.9ms
# Speed: 10.6ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.98, hand 0.02, arm 0.00, 33.0ms
# Speed: 10.1ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.7ms
# Speed: 10.1ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.03, arm 0.00, 39.3ms
# Speed: 11.4ms preprocess, 39.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.01, 37.6ms
# Speed: 9.7ms preprocess, 37.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 38.0ms
# Speed: 10.7ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.04, arm 0.00, 36.6ms
# Speed: 10.0ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.03, arm 0.00, 47.7ms
# Speed: 9.4ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.00, 31.6ms
# Speed: 10.9ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 34.8ms
# Speed: 10.4ms preprocess, 34.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 30.9ms
# Speed: 10.0ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 30.4ms
# Speed: 10.0ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 30.0ms
# Speed: 10.6ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 28.8ms
# Speed: 10.2ms preprocess, 28.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 30.7ms
# Speed: 10.1ms preprocess, 30.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.97, hand 0.02, arm 0.01, 30.6ms
# Speed: 10.0ms preprocess, 30.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.7ms
# Speed: 9.6ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 33.3ms
# Speed: 10.5ms preprocess, 33.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.03, arm 0.01, 30.2ms
# Speed: 10.1ms preprocess, 30.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.5ms
# Speed: 10.9ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.93, hand 0.05, arm 0.01, 33.0ms
# Speed: 10.3ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.01, 32.6ms
# Speed: 10.5ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.05, arm 0.02, 30.1ms
# Speed: 10.0ms preprocess, 30.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.01, 32.4ms
# Speed: 10.2ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.01, 31.9ms
# Speed: 9.8ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.0ms
# Speed: 10.6ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 33.2ms
# Speed: 10.5ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.01, 32.3ms
# Speed: 10.3ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.1ms
# Speed: 9.8ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.8ms
# Speed: 10.1ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.7ms
# Speed: 10.5ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 31.4ms
# Speed: 10.0ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.03, arm 0.01, 38.8ms
# Speed: 10.6ms preprocess, 38.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.03, arm 0.02, 40.2ms
# Speed: 11.2ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.02, 38.8ms
# Speed: 10.2ms preprocess, 38.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.96, hand 0.03, arm 0.01, 36.5ms
# Speed: 10.8ms preprocess, 36.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.03, arm 0.01, 53.2ms
# Speed: 9.7ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.01, 31.0ms
# Speed: 10.5ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.02, 32.4ms
# Speed: 10.3ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 31.8ms
# Speed: 10.3ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.01, 32.6ms
# Speed: 9.9ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.95, hand 0.04, arm 0.02, 32.0ms
# Speed: 10.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 not_hand 0.94, hand 0.04, arm 0.02, 33.2ms
# Speed: 9.9ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
